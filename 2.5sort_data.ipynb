# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# combine all the states data into a single dataframe from cleaned_dataset file
df_sort = pd.read_csv('working_datasets/cleaned_data.csv')

# %%
# first sort according to state names, then sort according to district names within each state
df = df_sort.sort_values(by=['state', 'district']).reset_index(drop=True)
print("Data sorted by state and district names.")
# Out:
# Data sorted by state and district names.

# %%
df
# Out:
#               date                      state        district  pincode  \
# 0       2025-09-01  Andaman_&_Nicobar_Islands        Andamans   744101
# 1       2025-09-09  Andaman_&_Nicobar_Islands        Andamans   744103
# 2       2025-09-11  Andaman_&_Nicobar_Islands        Andamans   744103
# 3       2025-09-18  Andaman_&_Nicobar_Islands        Andamans   744103
# 4       2025-09-18  Andaman_&_Nicobar_Islands        Andamans   744101
# ...            ...                        ...             ...      ...
# 548617  2025-12-29                West_Bengal  West_Midnapore   721301
# 548618  2025-12-29                West_Bengal  West_Midnapore   721517
# 548619  2025-12-29                West_Bengal  West_Midnapore   721305
# 548620  2025-12-29                West_Bengal  West_Midnapore   721212
# 548621  2025-09-12                 Westbengal         Hooghly   712247
#
#         bio_age_5_17  bio_age_17_  demo_age_5_17  demo_age_17_  age_0_5  \
# ...

# %%
df.to_csv('working_datasets/sorted_by_states_and_districts.csv', index=False)
